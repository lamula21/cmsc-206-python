# %% [markdown]
# # [Intro to Tweepy](https://towardsdatascience.com/my-first-twitter-app-1115a327349e)

# %% [markdown]
# The first step in analyzing data is finding data to analyze. And a great place to find data is Twitter.
#
# Twitter’s API is famously well documented, making it a great place to get started creating your own datasets.
#
# In this tutorial, we’ll cover:
# - Creating a twitter app
# - Getting tweets with Tweepy
# - Extracting tweet attributes

# %%
import tweepy

# Variables that contains the credentials to access Twitter API
ACCESS_TOKEN = '1507476365209223177-tT7Ur8dc3zTqinEuFF3YwP9nTcbWqY'
ACCESS_SECRET = 'z3cmW4PsR7SZtZG7harfHuBwFDYIss5No1XZbp9GJbr06'
CONSUMER_KEY = 'zkHL8gUupR20SVVlmlruqrk2N'
CONSUMER_SECRET = 'sMYG0dAjk1ojegzeYIUX24iw983IWoIhXAYmfSLDxTwTtiAFJf'


# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api


# Create API object
api = connect_to_twitter_OAuth()

# %% [markdown]
# And now just to make sure it worked, lets print the most recent tweets from my stream:

# %%
# tweets from my stream
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Unemployment is at 3.6%, down from 6.4% when I took office.
#
# The fastest decline in unemployment to start a President’s term ever recorded.
# 🎶 Love Me Tender 🎶
# Thanks for stopping by the White House, @fred_guttenberg. It’s always good to see you. Keep the faith and keep up t… https://t.co/0fWU4Tn0yI
# One year ago, a lone gunman took the lives of eight people — four of whom were Sikh — at a FedEx facility in Indian… https://t.co/BVEI3KiFi7
# Thanks for the support! https://t.co/nY4nyRfqcl
# We created 365,000 new manufacturing jobs in America just last year.
#
# The best year for U.S. manufacturing jobs in… https://t.co/TBBxsoxuyb
# Today, we learned that in March, twelve states hit record low unemployment. More families than ever before — in sta… https://t.co/aHY9Y3m3f9
# Jill and I join our fellow Christians in observing Good Friday. Today, we remember Jesus’s sacrifice on the cross,… https://t.co/JwbJ22hVEa
# Happy Passover to all who celebrate in America, Israel, and around the world. May God bless you all during this sea… https://t.co/yYtVv0E14z
# If we can keep coming together and invest in the backbone of America — in our great universities, hardworking famil… https://t.co/aXX3ri3cSN
# Today is significant for many South Asians — especially Sikhs. On Vaisakhi, Sikhs celebrate the formalization of th… https://t.co/ErSRPrgBpT
# 🤔 https://t.co/PfqYpLiuVd
# i♥️u
# Jill and I send warm greetings on Mahavir Jayanti to people of the Jain faith. This is a day to strive for peace, h… https://t.co/s0hHQ4nmbN
# Today, my Administration released the first-ever Equity Action Plans.
#
# Laying out more than 300 concrete commitment… https://t.co/RinFegt62J
# From Day One, every action I’ve taken to rebuild our economy has been guided by one principle: Make it in America.… https://t.co/l96XL0R384
# Taking Twitter private at $54.20 should be up to shareholders, not the board
# Will endeavor to keep as many shareholders in privatized Twitter as allowed by law
# Tune in as I deliver remarks on our efforts to lower costs, rebuild supply chains, and lay a foundation for economi… https://t.co/ZIslDhA0dg
# American manufacturing is coming back. And when we build more in America, it increases our economic capacity and he… https://t.co/6jcIGdbguG

# %% [markdown]
# ## Get a User’s Tweets

# %% [markdown]
# Tweepy has a useful method that returns the most recent statuses posted from the specified user.
#
# Let’s use this to see what Donald Trump is tweeting today:

# %%
# tweets from a specific user
biden_tweets = api.user_timeline( screen_name = 'JoeBiden')
for tweet in biden_tweets:
    print(tweet.text)
# Out:
# When we build more in America, we increase economic capacity, and ultimately it helps lower everyday prices for fam… https://t.co/Yfa3P4zG0e
# From day one, every action I've taken to rebuild our economy has been guided by one principle—made in America. It m… https://t.co/dWP7qr2v3k
# RT @POTUS: Jill and I join our fellow Christians in observing Good Friday. Today, we remember Jesus’s sacrifice on the cross, pray for all…
# RT @POTUS: Happy Passover to all who celebrate in America, Israel, and around the world. May God bless you all during this season of renewa…
# To help deal with Putin’s Price Hike, I’ve authorized the use of 1 million barrels per day on average for the next… https://t.co/TarZELP5wO
# RT @POTUS: Jill and I are praying for those injured in the New York City subway shooting. We are grateful for the first responders and civi…
# America is back to work.
#
# Our economy added 7.9 million jobs since I took office—more jobs created on average per… https://t.co/jhXHsZM38k
# Today is a good day—a day that history is going to remember. https://t.co/gskJzbu2DK
# RT @POTUS: Judge Jackson brings a rare combination of experience and qualifications to the Court.
#
# A federal judge who served on the secon…
# RT @POTUS: Today is a good day for America. A day that history will remember. Tune in as the Vice President, Judge Ketanji Brown Jackson, a…
# RT @POTUS: Historic moment for our courts and for our country. Congratulations, Judge Jackson. https://t.co/eLSfs1QoHB
# Congratulations, Ketanji Brown Jackson. https://t.co/CGe6fdl7gk
# RT @POTUS: Judge Jackson’s confirmation was a historic moment for our nation. We’ve taken another step toward making our highest court refl…
# Over the last four weeks, fewer Americans filed initial claims for unemployment insurance than any time in our nati… https://t.co/An6NUY1GvN
# Today, we enshrine in law our recognition that the Postal Service is fundamental to our economy, to our democracy,… https://t.co/16nQT3sCpM
# If Republicans have their way, up to 100 million Americans with preexisting conditions could once again be denied h… https://t.co/GGRorUwoIW
# RT @POTUS: Today, my Administration is extending the pause on federal student loan repayments through August 31st, 2022. https://t.co/xwicA…
# Over 31 million people now have health insurance through the Affordable Care Act.
# 4 out of 5 Americans can find qua… https://t.co/RP6A70ilLp
# Mr. President, welcome back to the White House.
# https://t.co/JY2pjxOQKd
# RT @POTUS: It’s an honor to welcome my friend President @BarackObama back to the White House. I look forward to discussing the big step we’…

# %% [markdown]
# The `user_timeline()` function returns a tweet object. From Twitter’s documentation we can see that each tweet object has a long list of attributes including the text attribute that we used above.
#
# We can write a function to extract the attributes we’re interested in and create a dataframe:

# %%
import pandas as pd

# fuction to extract data from tweet object
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
    # loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        text = tweet.text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id, 
                          'text':text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})
    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'text',
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'reply_to_status',
                                           'reply_to_user',
                                           'retweets',
                                           'favorites'])
    return df


df = extract_tweet_attributes(biden_tweets)
df
# Out:
#                tweet_id                                               text  \
# 0   1515033214833860611  When we build more in America, we increase eco...
# 1   1515014340390400003  From day one, every action I've taken to rebui...
# 2   1514989532986458119  RT @POTUS: Jill and I join our fellow Christia...
# 3   1514960446238908419  RT @POTUS: Happy Passover to all who celebrate...
# 4   1514274974630035460  To help deal with Putin’s Price Hike, I’ve aut...
# 5   1513977893898100738  RT @POTUS: Jill and I are praying for those in...
# 6   1512891350206791681  America is back to work. \n\nOur economy added...
# 7   1512590810239356937  Today is a good day—a day that history is goin...
# 8   1512503378693263361  RT @POTUS: Judge Jackson brings a rare combina...
# 9   1512468142345363462  RT @POTUS: Today is a good day for America. A ...
# 10  1512206336955756550  RT @POTUS: Historic moment for our courts and ...
# 11  1512173878285684737  Congratulations, Ketanji Brown Jackson. https:...
# 12  1512139538705129493  RT @POTUS: Judge Jackson’s confirmation was a ...
# 13  1512114912935530504  Over the last four weeks, fewer Americans file...
# 14  1511840425358893060  Today, we enshrine in law our recognition that...
# 15  1511742091805831176  If Republicans have their way, up to 100 milli...
# 16  1511716630765711360  RT @POTUS: Today, my Administration is extendi...
# 17  1511507984463052815  Over 31 million people now have health insuran...
# 18  1511481058809856006  Mr. President, welcome back to the White House...
# 19  1511398798597230601  RT @POTUS: It’s an honor to welcome my friend ...
#
#     favorite_count  retweet_count                created_at           source  \
# 0             6354            985 2022-04-15 18:24:01+00:00    Sprout Social
# 1            18162           2771 2022-04-15 17:09:01+00:00    Sprout Social
# 2                0           8146 2022-04-15 15:30:26+00:00    Sprout Social
# 3                0           4113 2022-04-15 13:34:51+00:00    Sprout Social
# 4            39745           5117 2022-04-13 16:11:02+00:00    Sprout Social
# 5                0           3569 2022-04-12 20:30:32+00:00    Sprout Social
# 6            20019           3088 2022-04-09 20:33:00+00:00    Sprout Social
# 7            22581           3231 2022-04-09 00:38:46+00:00    Sprout Social
# 8                0           1815 2022-04-08 18:51:21+00:00  Twitter Web App
# 9                0           1700 2022-04-08 16:31:20+00:00  Twitter Web App
# 10               0          17235 2022-04-07 23:11:00+00:00    Sprout Social
# 11          109180          10638 2022-04-07 21:02:02+00:00    Sprout Social
# 12               0          18313 2022-04-07 18:45:34+00:00  Twitter Web App
# 13            8403           1209 2022-04-07 17:07:43+00:00    Sprout Social
# 14           24404           2991 2022-04-06 22:57:00+00:00    Sprout Social
# 15            7236           1346 2022-04-06 16:26:16+00:00    Sprout Social
# 16               0           4807 2022-04-06 14:45:05+00:00  Twitter Web App
# 17           13576           2003 2022-04-06 00:56:00+00:00    Sprout Social
# 18           68382           4726 2022-04-05 23:09:01+00:00    Sprout Social
# 19               0          12526 2022-04-05 17:42:08+00:00  Twitter Web App
#
#    reply_to_status reply_to_user  retweets  favorites
# 0             None          None       985       6354
# 1             None          None      2771      18162
# 2             None          None      8146          0
# 3             None          None      4113          0
# 4             None          None      5117      39745
# 5             None          None      3569          0
# 6             None          None      3088      20019
# 7             None          None      3231      22581
# 8             None          None      1815          0
# 9             None          None      1700          0
# 10            None          None     17235          0
# 11            None          None     10638     109180
# 12            None          None     18313          0
# 13            None          None      1209       8403
# 14            None          None      2991      24404
# 15            None          None      1346       7236
# 16            None          None      4807          0
# 17            None          None      2003      13576
# 18            None          None      4726      68382
# 19            None          None     12526          0
