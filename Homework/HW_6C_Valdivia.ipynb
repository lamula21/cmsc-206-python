# %%
# Author: Jose Valdivia Rojas
# Course: CMSC 206
# Assignment 6C


# 1. Create the following three dictionaries: Gary, Alice, and Tyler 
Gary = {
  "name": "Gary",
  "homework": [90.0,97.0,75.0,92.0],
  "quizzes": [88.0,40.0,94.0],
  "tests": [75.0,90.0]
}
Alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
Tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Insert one additional dictionary (i.e., you) of your choice
Jose = {
  "name": "Tyler",
  "homework": [80.0, 90.0, 95.0, 88.0],
  "quizzes": [70.0, 92.2, 78.5],
  "tests": [99.0, 60.5]
}

# Create a new list named students that contains four dictionary items
students = list()

students.append(Gary.copy())
students.append(Alice.copy())
students.append(Tyler.copy())
#students.append(Jose.copy())

print(students)


# for each student in your students list, print out that student's data, as follows:
''' 	print the student's name
    	print the student's homework
    	print the student's quizzes
    	print the student's tests
'''

i = 1
for eachStudent in students:
    print(f"\n\nStudent {i} info")
    print(f"Student's name: {eachStudent['name']}")
    print(f"Student's homework: {eachStudent['homework']}")
    print(f"Student's quizzes: {eachStudent['quizzes']}")
    print(f"Student's tests: {eachStudent['tests']}")
    i += 1

# Write a function average that takes a list of numbers and returns the average
''' 	Define a function called average that has one argument, numbers
    	Inside that function, call the built-in sum() function with the numbers list as a parameter. Store the result in a variable called total
    	Use float() to convert total and store the result in total
    	Divide total by the length of the numbers list. Use the built-in len() function to calculate that
    	Return that result
'''
def average(numbers):
    total = float(sum(numbers))
    total = total / len(numbers)
    return total


# Write a function called get_average that takes a student dictionary (like lloyd, alice, or tyler) as input and returns his/her weighted average.
""" 	Define a function called get_average that takes one argument called student.
    	Make a variable homework that stores the average() of student["homework"].
    	Repeat step 2 for "quizzes" and "tests".
    	Multiply the 3 averages by their weights and return the sum of those three. Homework is 10%, quizzes are 30% and tests are 60%.
"""
def get_average(student):
    homework = average(student["homework"]) * 0.1
    quizzes = average(student["quizzes"]) * 0.3
    tests = average(student["tests"]) * 0.6
    return homework + quizzes + tests



# Define a function called get_class_average that has one argument, students. You can expect students to be a list containing your three students.
''' 	First, make an empty list called results.
    	For each student item in the class list, calculate get_average(student) and then call results.append() with that result.
    	Finally, return the result of calling average() with results.
'''
def get_class_average(students):
    results = list()
    for eachStudent in students:
        average_of_eachStudent = get_average(eachStudent)
        results.append(average_of_eachStudent)
    return average(results)


# Finally, print out the result of calling get_class_average with the students list. 
class_averageScore = get_class_average(students)
print("\n\nThe average score for this class is", "{:.2f}".format(class_averageScore))



# 2.	Using a dictionary, perform a task of your choice
#       This is for you to practice using a dictionary.  That’s the purpose of this portion of the assignment

# ANOTHER USEFUL METHODS DICTIONARY
#   Dictionary - Append to a key
print()
food = {'Nishant': 'Burger'}
food['Nishant'] = [4]
food['Nishant'].append('Pizza')
print(food) # {  'Nishant'  :   [4, 'Pizza']  }


# Append to lists of each key inside a dictionary
print()
myvalue = {'Akash': [], 'Bharat': []}
myvalue['Akash'] += [1,3]
myvalue['Bharat'] += [4,6]
print(myvalue)     # {'Akash': [1, 3]   ,   'Bharat': [4, 6]}

# Convert list to dictionary
print()
name = ['Tom', 'Mack', 'Jim']
dictionary = dict.fromkeys(name, 'pass')    # dict.fromkeys( a_list , 'defaultValue_for_the_key')
print(dictionary)
# Out:
# [{'name': 'Gary', 'homework': [90.0, 97.0, 75.0, 92.0], 'quizzes': [88.0, 40.0, 94.0], 'tests': [75.0, 90.0]}, {'name': 'Alice', 'homework': [100.0, 92.0, 98.0, 100.0], 'quizzes': [82.0, 83.0, 91.0], 'tests': [89.0, 97.0]}, {'name': 'Tyler', 'homework': [0.0, 87.0, 75.0, 22.0], 'quizzes': [0.0, 75.0, 78.0], 'tests': [100.0, 100.0]}]
#
#
# Student 1 info
# Student's name: Gary
# Student's homework: [90.0, 97.0, 75.0, 92.0]
# Student's quizzes: [88.0, 40.0, 94.0]
# Student's tests: [75.0, 90.0]
#
#
# Student 2 info
# Student's name: Alice
# Student's homework: [100.0, 92.0, 98.0, 100.0]
# Student's quizzes: [82.0, 83.0, 91.0]
# Student's tests: [89.0, 97.0]
#
#
# Student 3 info
# Student's name: Tyler
# Student's homework: [0.0, 87.0, 75.0, 22.0]
# Student's quizzes: [0.0, 75.0, 78.0]
# Student's tests: [100.0, 100.0]
#
#
# The average score for this class is 83.87
#
# {'Nishant': [4, 'Pizza']}
#
# {'Akash': [1, 3], 'Bharat': [4, 6]}
#
# {'Tom': 'pass', 'Mack': 'pass', 'Jim': 'pass'}
